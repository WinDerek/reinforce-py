# %%
# For inline plotting
# %matplotlib inline

# For auto reloading
# %load_ext autoreload
# %autoreload 2

# %%
import matplotlib.pyplot as plt
import pickle

# mkdir
from pathlib import Path
Path("./figure").mkdir(parents=True, exist_ok=True)

filename = "dbs_value_iteration_experiments_results.pkl"
with open(filename, "rb") as f:
    experiments_results = pickle.load(f)

COLOR_LIST = [ '#999999', '#E69F00', '#56B4E9', '#009E73', '#F0E442', '#0072B2', '#D55E00', '#000000' ]
MARKEVERY = 10
MARKER_SIZE = 25.0
LINE_WIDTH = 2.0
FONT_SIZE = 24.0
FONT_SIZE_TICK = 24.0
FIGSIZE = (16,9)
GRID = False
FONT_WEIGHT = "normal"

for index, agent_name in enumerate(experiments_results['agent_name_list']):
    print("#{:d}: \'{:s}\'".format(index, agent_name))

first_list = range(8)
second_list = [ 4, 5, 6, 7, 8, 9 ]
static_list = [ 0, 1, 2, 3, 4 ]
dynamic_list = [ 7, 8, 9, 10, 11, 12 ]

# Static
fig, ax = plt.subplots(figsize=(16, 9), dpi=120)
for index, agent_index in enumerate(static_list):
    agent_name = experiments_results['agent_name_list'][agent_index]
    value_loss_array = experiments_results['value_loss_2darray'][agent_index]
    ax.plot(range(1, value_loss_array.shape[0] + 1), value_loss_array, markevery=1, linestyle='-', color=COLOR_LIST[index], label=agent_name, markersize=MARKER_SIZE, linewidth=LINE_WIDTH)
ax.legend()
ax.set_xlabel(r'Step $t$', fontsize=FONT_SIZE, fontweight=FONT_WEIGHT)
ax.set_ylabel(r'Value Loss', fontsize=FONT_SIZE, fontweight=FONT_WEIGHT)
# Save the figure
fig.savefig('./figure/dbs_value_iteration_static.pdf', format='pdf', bbox_inches='tight')
# fig, ax = plt.subplots(figsize=(16, 9), dpi=120)
# for index, agent_index in enumerate(static_list):
#     agent_name = experiments_results['agent_name_list'][agent_index]
#     value_loss_array = experiments_results['value_loss_2darray'][agent_index]
#     ax.plot(range(1, 100 + 1), value_loss_array[:100], '.', markevery=1, linestyle='-', color=COLOR_LIST[index], label=agent_name, markersize=12, linewidth=2)
# ax.legend()

# Original (first list)
fig, ax = plt.subplots(figsize=(16, 9), dpi=120)
for index, agent_index in enumerate(first_list):
    agent_name = experiments_results['agent_name_list'][agent_index]
    value_loss_array = experiments_results['value_loss_2darray'][agent_index]
    ax.plot(range(1, value_loss_array.shape[0] + 1), value_loss_array, markevery=1, linestyle='-', color=COLOR_LIST[index], label=agent_name, markersize=MARKER_SIZE, linewidth=LINE_WIDTH)
ax.legend()
ax.set_xlabel(r'Step $t$', fontsize=FONT_SIZE, fontweight=FONT_WEIGHT)
ax.set_ylabel(r'Value Loss', fontsize=FONT_SIZE, fontweight=FONT_WEIGHT)
# fig, ax = plt.subplots(figsize=(16, 9), dpi=120)
# for index, agent_index in enumerate(first_list):
#     agent_name = experiments_results['agent_name_list'][agent_index]
#     value_loss_array = experiments_results['value_loss_2darray'][agent_index]
#     ax.plot(range(1, 100 + 1), value_loss_array[:100], '.', markevery=1, linestyle='-', color=COLOR_LIST[index], label=agent_name, markersize=12, linewidth=2)
# ax.legend()

# # (second list)
# fig, ax = plt.subplots(figsize=(16, 9), dpi=120)
# for index, agent_index in enumerate(second_list):
#     agent_name = experiments_results['agent_name_list'][agent_index]
#     value_loss_array = experiments_results['value_loss_2darray'][agent_index]
#     ax.plot(range(1, value_loss_array.shape[0] + 1), value_loss_array, markevery=1, linestyle='-', color=COLOR_LIST[index], label=agent_name, markersize=12, linewidth=2)
# ax.legend()
# fig, ax = plt.subplots(figsize=(16, 9), dpi=120)
# for index, agent_index in enumerate(second_list):
#     agent_name = experiments_results['agent_name_list'][agent_index]
#     value_loss_array = experiments_results['value_loss_2darray'][agent_index]
#     ax.plot(range(1, 100 + 1), value_loss_array[:100], '.', markevery=1, linestyle='-', color=COLOR_LIST[index], label=agent_name, markersize=12, linewidth=2)
# ax.legend()

# Dynamic
fig, ax = plt.subplots(figsize=(16, 9), dpi=120)
for index, agent_index in enumerate(dynamic_list):
    agent_name = experiments_results['agent_name_list'][agent_index]
    value_loss_array = experiments_results['value_loss_2darray'][agent_index]
    ax.plot(range(1, value_loss_array.shape[0] + 1), value_loss_array, markevery=1, linestyle='-', color=COLOR_LIST[index], label=agent_name, markersize=MARKER_SIZE, linewidth=LINE_WIDTH)
ax.legend()
ax.set_xlabel(r'Step $t$', fontsize=FONT_SIZE, fontweight=FONT_WEIGHT)
ax.set_ylabel(r'Value Loss', fontsize=FONT_SIZE, fontweight=FONT_WEIGHT)
# Save the figure
fig.savefig('./figure/dbs_value_iteration_dynamic.pdf', format='pdf', bbox_inches='tight')
# fig, ax = plt.subplots(figsize=(16, 9), dpi=120)
# for index, agent_index in enumerate(dynamic_list):
#     agent_name = experiments_results['agent_name_list'][agent_index]
#     value_loss_array = experiments_results['value_loss_2darray'][agent_index]
#     ax.plot(range(1, 100 + 1), value_loss_array[:100], '.', markevery=1, linestyle='-', color=COLOR_LIST[index], label=agent_name, markersize=MARKER_SIZE, linewidth=LINE_WIDTH)
# ax.legend()
# ax.set_xlabel(r'Step $t$', fontsize=FONT_SIZE, fontweight=FONT_WEIGHT)
# ax.set_ylabel(r'Value Loss', fontsize=FONT_SIZE, fontweight=FONT_WEIGHT)
# fig, ax = plt.subplots(figsize=(16, 9), dpi=120)
# for index, agent_index in enumerate(dynamic_list):
#     agent_name = experiments_results['agent_name_list'][agent_index]
#     value_loss_array = experiments_results['value_loss_2darray'][agent_index]
#     ax.plot(range(1, value_loss_array.shape[0] + 1), value_loss_array, markevery=1, linestyle='-', color=COLOR_LIST[index], label=agent_name, markersize=MARKER_SIZE, linewidth=LINE_WIDTH)
# ax.legend()
# ax.set_ylim(0.0, 1e-12)
# ax.set_xlabel(r'Step $t$', fontsize=FONT_SIZE, fontweight=FONT_WEIGHT)
# ax.set_ylabel(r'Value Loss', fontsize=FONT_SIZE, fontweight=FONT_WEIGHT)
# Out:
# #0: '$\beta_t = 0.1$'
# #1: '$\beta_t = 1$'
# #2: '$\beta_t = 10$'
# #3: '$\beta_t = 100$'
# #4: '$\beta_t = 1000$'
# #5: '$\beta_t = t$'
# #6: '$\beta_t = t^2$'
# #7: '$\beta_t = t^3$'
# #8: '$\beta_t = \sqrt{t}$'
# #9: '$\beta_t = \log t$'
# #10: '$\beta_t = t \log t$'
# #11: '$\beta_t = t^2 \log t$'
# #12: '$\beta_t = t^3 \log t$'

# %%
import pickle


# Load the optimal v
filename = "dbs_value_iteration_optimal_v_array.pkl"
with open(filename, "rb") as f:
    optimal_v_array = pickle.load(f)

    
print(optimal_v_array)
print(optimal_v_array[-2])
# Out:
# [0.17086822 0.21094842 0.23438714 0.26043015 0.28936683 0.32151871
#  0.39693667 0.44104075 0.18985358 0.23438714 0.26043015 0.28936683
#  0.32151871 0.35724301 0.44104075 0.49004528 0.21094842 0.26043015
#  0.28936683 0.32151871 0.35724301 0.39693667 0.49004528 0.54449475
#  0.23438714 0.28936683 0.32151871 0.35724301 0.39693667 0.44104075
#  0.54449475 0.60499417 0.26043015 0.32151871 0.35724301 0.39693667
#  0.44104075 0.49004528 0.60499417 0.67221574 0.28936683 0.35724301
#  0.39693667 0.44104075 0.49004528 0.54449475 0.67221574 0.74690638
#  0.32151871 0.39693667 0.44104075 0.49004528 0.54449475 0.60499417
#  0.74690638 0.82989598 0.35724301 0.39693667 0.44104075 0.49004528
#  0.54449475 0.60499417 0.67221574 0.74690638 0.82989598 0.92210664
#  0.32151871 0.39693667 0.44104075 0.49004528 0.54449475 0.60499417
#  1.02456293 0.28936683 0.35724301 0.39693667 0.44104075 0.49004528
#  0.54449475 0.1537814  1.13840326]
# 0.15378139990614256
